# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

# %%
p1 = np.linspace(0.1,0.9,100)
p2 = np.linspace(0.1,0.5,100)

# %%
P1, P2 = np.meshgrid(p1,p2)

# %%
res = np.empty_like(P1)
res = (P1*P2+2*(1-P1)*P2+2*P1*(1-P2)+(1-P1)*(1-P2))/4

# %%
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(2,1,1,projection='3d')
superficie = ax.plot_surface(P1,P2,Z,cmap=cm.coolwarm)
ax.set_xlabel("P1",c='k',fontsize=15)
ax.set_ylabel("\n\n\nP2",c='k',fontsize=15)
ax.view_init(45,85)

# %%
print('La probabilidad de minimo es', round(np.min(res),2))
print('La probabilidad de maxima es', round(np.max(res),1))
# Out:
# La probabilidad de minimo es 0.3
# La probabilidad de maxima es 0.5
